# %% [markdown]
# ## Time series dataset from [BLS](https://www.bls.gov/data/#unemployment) for any macroeconomic data -  [COVID - Google Trends ](https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide)

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

# %%
data = pd.read_csv('covid19.csv')
data.head(10)
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
# 5  09/12/2020    9     12  2020    135      13             Afghanistan    AF
# 6  08/12/2020    8     12  2020    200       6             Afghanistan    AF
# 7  07/12/2020    7     12  2020    210      26             Afghanistan    AF
# 8  06/12/2020    6     12  2020    234      10             Afghanistan    AF
# 9  05/12/2020    5     12  2020    235      18             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61900 entries, 0 to 61899
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     61900 non-null  object
#  1   day                                                         61900 non-null  int64
#  2   month                                                       61900 non-null  int64
#  3   year                                                        61900 non-null  int64
#  4   cases                                                       61900 non-null  int64
#  5   deaths                                                      61900 non-null  int64
#  6   countriesAndTerritories                                     61900 non-null  object
# ...

# %%
data.isna().sum()
# Out:
# dateRep                                                          0
# day                                                              0
# month                                                            0
# year                                                             0
# cases                                                            0
# deaths                                                           0
# countriesAndTerritories                                          0
# geoId                                                          275
# countryterritoryCode                                           123
# popData2019                                                    123
# continentExp                                                     0
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000    2879
# dtype: int64

# %%
data.shape
# Out:
# (61900, 12)

# %%
missing_values = data.isna().sum()
missing_values.plot(kind='bar', figsize=(10,7))
# Out:
# <AxesSubplot:>

# %%
data.median().iloc[1]
# Out:
# 7.0

# %%
data.fillna(data.median().iloc[1])
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      14/12/2020   14     12  2020    746       6             Afghanistan
# 1      13/12/2020   13     12  2020    298       9             Afghanistan
# 2      12/12/2020   12     12  2020    113      11             Afghanistan
# 3      11/12/2020   11     12  2020     63      10             Afghanistan
# 4      10/12/2020   10     12  2020    202      16             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 61895  25/03/2020   25      3  2020      0       0                Zimbabwe
# 61896  24/03/2020   24      3  2020      0       1                Zimbabwe
# 61897  23/03/2020   23      3  2020      0       0                Zimbabwe
# 61898  22/03/2020   22      3  2020      1       0                Zimbabwe
# 61899  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
data.drop(columns=['day', 'month', 'year', 'popData2019', ], inplace = True)

# %%
data
# Out:
#           dateRep  cases  deaths countriesAndTerritories geoId  \
# 0      14/12/2020    746       6             Afghanistan    AF
# 1      13/12/2020    298       9             Afghanistan    AF
# 2      12/12/2020    113      11             Afghanistan    AF
# 3      11/12/2020     63      10             Afghanistan    AF
# 4      10/12/2020    202      16             Afghanistan    AF
# ...           ...    ...     ...                     ...   ...
# 61895  25/03/2020      0       0                Zimbabwe    ZW
# 61896  24/03/2020      0       1                Zimbabwe    ZW
# 61897  23/03/2020      0       0                Zimbabwe    ZW
# 61898  22/03/2020      1       0                Zimbabwe    ZW
# 61899  21/03/2020      1       0                Zimbabwe    ZW
#
#       countryterritoryCode continentExp  \
# 0                      AFG         Asia
# 1                      AFG         Asia
# 2                      AFG         Asia
# 3                      AFG         Asia
# ...

# %%
data.describe()
# Out:
#                cases        deaths  \
# count   61900.000000  61900.000000
# mean     1155.147237     26.055460
# std      6779.224479    131.227055
# min     -8261.000000  -1918.000000
# 25%         0.000000      0.000000
# 50%        15.000000      0.000000
# 75%       273.000000      4.000000
# max    234633.000000   4928.000000
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# count                                       59021.000000
# mean                                           66.320586
# std                                           162.329240
# min                                          -147.419587
# 25%                                             0.757526
# 50%                                             6.724045
# 75%                                            52.572719
# max                                          1900.836210

# %%
data['dateRep'] = pd.to_datetime(data['dateRep'])
data
# Out:
#          dateRep  cases  deaths countriesAndTerritories geoId  \
# 0     2020-12-14    746       6             Afghanistan    AF
# 1     2020-12-13    298       9             Afghanistan    AF
# 2     2020-12-12    113      11             Afghanistan    AF
# 3     2020-11-12     63      10             Afghanistan    AF
# 4     2020-10-12    202      16             Afghanistan    AF
# ...          ...    ...     ...                     ...   ...
# 61895 2020-03-25      0       0                Zimbabwe    ZW
# 61896 2020-03-24      0       1                Zimbabwe    ZW
# 61897 2020-03-23      0       0                Zimbabwe    ZW
# 61898 2020-03-22      1       0                Zimbabwe    ZW
# 61899 2020-03-21      1       0                Zimbabwe    ZW
#
#       countryterritoryCode continentExp  \
# 0                      AFG         Asia
# 1                      AFG         Asia
# 2                      AFG         Asia
# 3                      AFG         Asia
# ...

# %%
data.set_index('dateRep', inplace=True)
data.head()
# Out:
#             cases  deaths countriesAndTerritories geoId countryterritoryCode  \
# dateRep
# 2020-12-14    746       6             Afghanistan    AF                  AFG
# 2020-12-13    298       9             Afghanistan    AF                  AFG
# 2020-12-12    113      11             Afghanistan    AF                  AFG
# 2020-11-12     63      10             Afghanistan    AF                  AFG
# 2020-10-12    202      16             Afghanistan    AF                  AFG
#
#            continentExp  \
# dateRep
# 2020-12-14         Asia
# 2020-12-13         Asia
# 2020-12-12         Asia
# 2020-11-12         Asia
# 2020-10-12         Asia
#
#             Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# dateRep
# 2020-12-14                                           9.013779
# 2020-12-13                                           7.052776
# 2020-12-12                                           6.868768
# 2020-11-12                                           7.134266
# ...

# %% [markdown]
# ## Graphing
# * Visualization is a powerful tool for an analyst to recognize any pattern in the data.

# %%
import matplotlib.pyplot as plt
data.plot(figsize=(7,7), linewidth= 2, fontsize=15)
plt.xlabel('Year', fontsize=15)
# Out:
# Text(0.5, 0, 'Year')
